# %%
#Problem 6

from matplotlib import pyplot as plt

import numpy as np
from numpy import Infinity as inf
# %matplotlib inline

# %%
#Plot equation

#Define constants
R = 1
A = 1
x = 0

 


r = np.linspace(0,10, 1000)

V = A*((np.exp((R-r))-1)**2 - 1)

# %%
plt.plot(r,V,'b-')
plt.axhline(0,color = 'black')
plt.xlabel('r (m)')
plt.ylabel('V(r) (J)')
plt.title('Potential Energy vs Distance Between Two Atoms')
plt.savefig('MechHW4')

# %%
#Problem 5 Part a

#Define coefficients
x = np.linspace(-1.05,1.05, 100)
al = 1.0/np.sqrt(2)
k = np.sqrt(2)

V = (x**2)*(1-x**2)

plt.plot(x,V,'r-')
plt.axis([-1.3,1.3,-0.11,0.26])
plt.xlabel('x position (m)')
plt.ylabel('V(x) (J)')
plt.title('Potential vs x of a particle')
plt.savefig('PotentialX_HW4')
